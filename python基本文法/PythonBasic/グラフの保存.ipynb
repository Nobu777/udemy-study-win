# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,10,0.01)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.tight_layout()
plt.savefig("./data/test.png", dpi=300)
